# %% [markdown]
# <a href="https://colab.research.google.com/github/JiteshKumar9/Customer-Purchase-Prediction/blob/main/Customer%20Purchase%20Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
customer = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Customer%20Purchase.csv')

# %%
customer
# Out:
#     Customer ID  Age  Gender Education   Review Purchased
# 0          1021   30  Female    School  Average        No
# 1          1022   68  Female        UG     Poor        No
# 2          1023   70  Female        PG     Good        No
# 3          1024   72  Female        PG     Good        No
# 4          1025   16  Female        UG  Average        No
# 5          1026   31  Female    School  Average       Yes
# 6          1027   18    Male    School     Good        No
# 7          1028   60  Female    School     Poor       Yes
# 8          1029   65  Female        UG  Average        No
# 9          1030   74    Male        UG     Good       Yes
# 10         1031   98  Female        UG     Good       Yes
# 11         1032   74    Male        UG     Good       Yes
# 12         1033   51    Male    School     Poor        No
# 13         1034   57  Female    School  Average        No
# 14         1035   15    Male        PG     Poor       Yes
# ...

# %%
customer.head()
# Out:
#    Customer ID  Age  Gender Education   Review Purchased
# 0         1021   30  Female    School  Average        No
# 1         1022   68  Female        UG     Poor        No
# 2         1023   70  Female        PG     Good        No
# 3         1024   72  Female        PG     Good        No
# 4         1025   16  Female        UG  Average        No

# %%
customer.describe()
# Out:
#        Customer ID        Age
# count     50.00000  50.000000
# mean    1045.50000  54.160000
# std       14.57738  25.658161
# min     1021.00000  15.000000
# 25%     1033.25000  30.250000
# 50%     1045.50000  57.000000
# 75%     1057.75000  74.000000
# max     1070.00000  98.000000

# %%
customer.shape
# Out:
# (50, 6)

# %%
customer.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Education', 'Review', 'Purchased'], dtype='object')

# %%
y = customer['Purchased']
X = customer.drop(['Purchased','Customer ID'], axis=1)

# %%
X.replace({'Review':{'Poor':0,'Average':1,'Good':2}},inplace=True)
X.replace({'Education':{'School':0,'UG':1,'PG':2}},inplace=True)
X.replace({'Gender':{'Male': 0,'Female':1}},inplace=True)
# Out:
# <ipython-input-9-a67e26d52802>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X.replace({'Review':{'Poor':0,'Average':1,'Good':2}},inplace=True)
# <ipython-input-9-a67e26d52802>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X.replace({'Education':{'School':0,'UG':1,'PG':2}},inplace=True)
# ...

# %%
X.head()
# Out:
#    Age  Gender  Education  Review
# 0   30       1          0       1
# 1   68       1          1       0
# 2   70       1          2       2
# 3   72       1          2       2
# 4   16       1          1       1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((35, 4), (15, 4), (35,), (15,))

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7, 0],
#        [5, 3]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7333333333333333

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.64      1.00      0.78         7
#          Yes       1.00      0.50      0.67         8
#
#     accuracy                           0.73        15
#    macro avg       0.82      0.75      0.72        15
# weighted avg       0.83      0.73      0.72        15
